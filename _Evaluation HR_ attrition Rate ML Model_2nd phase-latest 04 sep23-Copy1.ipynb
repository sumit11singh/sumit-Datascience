# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"D:\Users\~sUMIt~\Desktop\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x.shape
# Out:
# (1387, 31)

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['Attrition']=df['Attrition'].apply(lambda x:1 if 'Yes' in x else 0 )

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.corr()['Attrition'].sort_values()
# Out:
# TotalWorkingYears          -0.171063
# JobLevel                   -0.169105
# YearsInCurrentRole         -0.160545
# MonthlyIncome              -0.159840
# Age                        -0.159205
# YearsWithCurrManager       -0.156199
# StockOptionLevel           -0.137145
# YearsAtCompany             -0.134392
# JobInvolvement             -0.130016
# JobSatisfaction            -0.103481
# EnvironmentSatisfaction    -0.103369
# WorkLifeBalance            -0.063939
# TrainingTimesLastYear      -0.059478
# DailyRate                  -0.056652
# RelationshipSatisfaction   -0.045872
# YearsSinceLastPromotion    -0.033019
# Education                  -0.031373
# PercentSalaryHike          -0.013478
# EmployeeNumber             -0.010577
# HourlyRate                 -0.006846
# PerformanceRating           0.002889
# MonthlyRate                 0.015170
# NumCompaniesWorked          0.043494
# DistanceFromHome            0.077924
# Attrition                   1.000000
# ...

# %%
df['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# # EDA Estimation(Data visulization)

# %% [markdown]
# Attrition Rate by Age

# %%
sns.countplot(hue=df.Attrition,x=df.Age)
plt.figure(figsize=(20,20))

# %%
df.groupby(['Age'],as_index=False)['Attrition'].sum().sort_values(by='Attrition',ascending=False)
# Out:
#     Age  Attrition
# 13   31         18
# 11   29         18
# 10   28         14
# 8    26         12
# 15   33         12
# 14   32         11
# 17   35         10
# 12   30          9
# 16   34          9
# 6    24          7
# 1    19          6
# 19   37          6
# 18   36          6
# 21   39          6
# 26   44          6
# 7    25          6
# 3    21          6
# 2    20          6
# 23   41          6
# 32   50          5
# 40   58          5
# 4    22          5
# 22   40          5
# 28   46          4
# 0    18          4
# 5    23          4
# 34   52          3
# 38   56          3
# 29   47          3
# 37   55          3
# 9    27          3
# 24   42          2
# 35   53          2
# 25   43          2
# 33   51          2
# 31   49          2
# 30   48          2
# 20   38          2
# 27   45          2
# 36   54          0
# 39   57          0
# 41   59          0
# 42   60          0

# %% [markdown]
# above graph is showing the each age group employee are leaving the company but this is most frequent in b/w age group 18-33

# %% [markdown]
# # attrition Count by Bussiness Travelling

# %%
ax=sns.countplot(x=df['BusinessTravel'],hue=df.Attrition,data=df)
for i in ax.containers:
    ax.bar_label(i)

# %%
df.groupby(['BusinessTravel'],as_index=False)['Attrition'].sum().sort_values(by='Attrition',ascending=False)
# Out:
#       BusinessTravel  Attrition
# 2      Travel_Rarely        156
# 1  Travel_Frequently         69
# 0         Non-Travel         12

# %% [markdown]
# max employee in company are those who travel rarely,count=1043 and attrittion count is highher=156

# %% [markdown]
# # Attrition count by department

# %%
 sns.histplot(df['Department'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Count'>

# %%
ax=sns.countplot(x=df['Department'],hue=df.Attrition,data=df)
for i in ax.containers:
    ax.bar_label(i)

# %%
df.groupby(['Department'],as_index=False)['Attrition'].sum().sort_values(by='Attrition',ascending=False)
# Out:
#                Department  Attrition
# 1  Research & Development        133
# 2                   Sales         92
# 0         Human Resources         12

# %% [markdown]
# Research& Development  Depart has the highest employee count in Organization=961,sales=446,HR=63 only ,
# Highest attrition count=133 in Research& Development Department

# %% [markdown]
# # Attrition count by Edducation field

# %%
ax=sns.countplot(x=df['EducationField'],hue=df.Attrition,data=df)
plt.xticks(rotation='vertical')
for i in ax.containers:
    ax.bar_label(i)

# %%
df.groupby(['EducationField'],as_index=False)['Attrition'].sum().sort_values(by='Attrition',ascending=False)
# Out:
#      EducationField  Attrition
# 1     Life Sciences         89
# 3           Medical         63
# 2         Marketing         35
# 5  Technical Degree         32
# 4             Other         11
# 0   Human Resources          7

# %% [markdown]
# highest No of employees who are working in company are from Life science background ,count=517,attrition count(leave the company)=89

# %%
sns.histplot(df['EmployeeNumber'])
# Out:
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='Count'>

# %% [markdown]
# # Attrition by RelationshipSatisfaction

# %%
ax=sns.countplot(df['RelationshipSatisfaction'])
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# 459 No's of employess has the RelationshipSatisfaction rating =3.0 and 432 are giving rating the 4.0 .

# %%
ax=sns.countplot(x=df['RelationshipSatisfaction'],hue=df.Attrition,data=df)
plt.xticks(rotation='vertical')
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# Relationshipsatisfaction is not a big factor for increasing attrition

# %% [markdown]
# # Attrition by TotalWorkingYears

# %%
sns.histplot(df['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Count'>

# %% [markdown]
# this grapgh showing the history of employess about Total working years which they are spenting in Organization.

# %%
ax=sns.histplot(x=df['TotalWorkingYears'],hue=df.Attrition,data=df)
plt.xticks(rotation='vertical')
for i in ax.containers:
    ax.bar_label(i)
    plt.figure(figsize=(25,15))

# %%
df.groupby(['TotalWorkingYears'],as_index=False)['Attrition'].sum().sort_values(by='Attrition',ascending=False)
# Out:
#     TotalWorkingYears  Attrition
# 1                   1         40
# 10                 10         25
# 6                   6         22
# 7                   7         18
# 5                   5         16
# 8                   8         16
# 4                   4         12
# 9                   9         10
# 2                   2          9
# 3                   3          9
# 11                 11          7
# 15                 15          5
# 0                   0          5
# 12                 12          5
# 14                 14          4
# 18                 18          4
# 13                 13          3
# 16                 16          3
# 17                 17          3
# 19                 19          3
# 24                 24          3
# 23                 23          2
# 20                 20          2
# 22                 22          2
# 39                 40          2
# 25                 25          1
# 26                 26          1
# ...

# %% [markdown]
# attrition is higher who has the experience b/w 1-10 yrs.

# %% [markdown]
# # Attrition analysis by Work life balance

# %%
sns.histplot(df['WorkLifeBalance'])
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Count'>

# %%
sns.boxplot(df['WorkLifeBalance'])
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance'>

# %%
ax=sns.histplot(x=df['WorkLifeBalance'],hue=df.Attrition)
plt.xticks(rotation='vertical')
for i in ax.containers:
    ax.bar_label(i)
    plt.figure(figsize=(25,15))

# %% [markdown]
# following graph is showing that rating is given by employees min is 2 and maximum is 3 which is avg rating and attrition count is higher where rating is provided by employee 3.0.

# %% [markdown]
# # EDA Analysis for Employee Spending years at compny

# %%
sns.boxplot(df['YearsAtCompany'])
# Out:
# <AxesSubplot:xlabel='YearsAtCompany'>

# %% [markdown]
# Above graph is showing that Employees which are working in company are in b/w 2.5yrs to 9 yrs.

# %% [markdown]
# # EDA Analysis for Employee spend in current  role

# %%
sns.boxplot(df['YearsInCurrentRole'])
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole'>

# %% [markdown]
# Employess yrs of spending which have in same role are 2 to 7 yrs.

# %% [markdown]
# # EDA Analysis for Employee YearsSinceLastPromotion

# %%
sns.boxplot(x=df['YearsSinceLastPromotion'])
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion'>

# %%
ax=sns.countplot(x=df['YearsSinceLastPromotion'],hue=df.Attrition,data=df)
plt.xticks(rotation='vertical')
plt.figure(figsize=(45,25))
for i in ax.containers:
    ax.bar_label(i)

# %%
df.groupby(['YearsSinceLastPromotion'],as_index=False)['Attrition'].sum().sort_values(by='Attrition',ascending=False)
# Out:
#     YearsSinceLastPromotion  Attrition
# 0                         0        110
# 1                         1         49
# 2                         2         27
# 7                         7         16
# 3                         3          9
# 6                         6          6
# 4                         4          5
# 9                         9          4
# 15                       15          3
# 5                         5          2
# 11                       11          2
# 13                       13          2
# 10                       10          1
# 14                       14          1
# 8                         8          0
# 12                       12          0

# %% [markdown]
# this analyis is showing that most of the Employees are leaving the company in 1st year if they are not promoted

# %%
sns.histplot(df['YearsWithCurrManager'])
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Count'>

# %%
sns.boxplot(df['YearsWithCurrManager'])
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager'>

# %% [markdown]
# above graph is showing that Most of the employess are spenting years with their current manager b/w 2.5 yrs to 7.5 yrs

# %%
ax=sns.countplot(x=df['YearsWithCurrManager'],hue=df.Attrition,data=df)
plt.xticks(rotation='vertical')
plt.figure(figsize=(45,25))
for i in ax.containers:
    ax.bar_label(i)

# %%
df.groupby(['YearsWithCurrManager'],as_index=False)['Attrition'].sum().sort_values(by='Attrition',ascending=False)
# Out:
#     YearsWithCurrManager  Attrition
# 0                      0         85
# 2                      2         50
# 7                      7         31
# 3                      3         19
# 4                      4         11
# 1                      1         11
# 8                      8         10
# 9                      9          6
# 6                      6          4
# 5                      5          4
# 10                    10          3
# 14                    14          2
# 11                    11          1
# 12                    12          0
# 13                    13          0
# 15                    15          0
# 16                    16          0
# 17                    17          0

# %% [markdown]
# attrittion count is higher,people dont want to work with their current manager.They are not satisfied with their current manager.

# %% [markdown]
# # O/P EDA Analysis

# %%
ax=sns.countplot(df['Attrition'])
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# Above Grapgh is showing theEmployees which are not leaving the organization have the count=1233,while leaving the company have count=237.

# %% [markdown]
# # Preprocessing for given Raw Data

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy='most_frequent')

# %%
 for i in df.columns:
        df[i]=imp.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
one=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=one.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1             2.0       1102         2.0                 1
# 1      49          0             1.0        279         1.0                 8
# 2      37          1             2.0       1373         1.0                 2
# 3      33          0             1.0       1392         1.0                 3
# 4      27          0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0             1.0        884         1.0                23
# 1466   39          0             2.0        613         1.0                 6
# 1467   27          0             2.0        155         1.0                 4
# 1468   49          0             1.0       1023         2.0                 2
# 1469   34          0             2.0        628         1.0                 8
#
# ...

# %%
df.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# BusinessTravel              float64
# DailyRate                     int64
# Department                  float64
# DistanceFromHome              int64
# Education                     int64
# EducationField              float64
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                      float64
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                     float64
# JobSatisfaction               int64
# MaritalStatus               float64
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# Over18                      float64
# OverTime                    float64
# PercentSalaryHike             int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# ...

# %% [markdown]
# # Defining the Correlation for given Dataset

# %%
df.corr()['Attrition'].sort_values()
# Out:
# TotalWorkingYears          -0.171063
# JobLevel                   -0.169105
# YearsInCurrentRole         -0.160545
# MonthlyIncome              -0.159840
# Age                        -0.159205
# YearsWithCurrManager       -0.156199
# StockOptionLevel           -0.137145
# YearsAtCompany             -0.134392
# JobInvolvement             -0.130016
# JobSatisfaction            -0.103481
# EnvironmentSatisfaction    -0.103369
# WorkLifeBalance            -0.063939
# TrainingTimesLastYear      -0.059478
# DailyRate                  -0.056652
# RelationshipSatisfaction   -0.045872
# YearsSinceLastPromotion    -0.033019
# Education                  -0.031373
# PercentSalaryHike          -0.013478
# EmployeeNumber             -0.010577
# HourlyRate                 -0.006846
# BusinessTravel              0.000074
# PerformanceRating           0.002889
# MonthlyRate                 0.015170
# EducationField              0.026846
# Gender                      0.029453
# ...

# %% [markdown]
# # there are 3 column whcich have non corealtion with Lable or o/p.so drop these columns

# %%
df=df.drop(['EmployeeCount','Over18','StandardHours'],axis=1)

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1             2.0       1102         2.0                 1
# 1      49          0             1.0        279         1.0                 8
# 2      37          1             2.0       1373         1.0                 2
# 3      33          0             1.0       1392         1.0                 3
# 4      27          0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0             1.0        884         1.0                23
# 1466   39          0             2.0        613         1.0                 6
# 1467   27          0             2.0        155         1.0                 4
# 1468   49          0             1.0       1023         2.0                 2
# 1469   34          0             2.0        628         1.0                 8
#
# ...

# %%
df.corr()['Attrition'].sort_values()
# Out:
# TotalWorkingYears          -0.171063
# JobLevel                   -0.169105
# YearsInCurrentRole         -0.160545
# MonthlyIncome              -0.159840
# Age                        -0.159205
# YearsWithCurrManager       -0.156199
# StockOptionLevel           -0.137145
# YearsAtCompany             -0.134392
# JobInvolvement             -0.130016
# JobSatisfaction            -0.103481
# EnvironmentSatisfaction    -0.103369
# WorkLifeBalance            -0.063939
# TrainingTimesLastYear      -0.059478
# DailyRate                  -0.056652
# RelationshipSatisfaction   -0.045872
# YearsSinceLastPromotion    -0.033019
# Education                  -0.031373
# PercentSalaryHike          -0.013478
# EmployeeNumber             -0.010577
# HourlyRate                 -0.006846
# BusinessTravel              0.000074
# PerformanceRating           0.002889
# MonthlyRate                 0.015170
# EducationField              0.026846
# Gender                      0.029453
# ...

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),annot=True,linewidths=0.6,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Describing Dataset

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# Attrition                 1470.0      0.161224     0.367863     0.0     0.00
# BusinessTravel            1470.0      1.607483     0.665455     0.0     1.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# Department                1470.0      1.260544     0.527792     0.0     1.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EducationField            1470.0      2.247619     1.331369     0.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# Gender                    1470.0      0.600000     0.490065     0.0     0.00
# ...

# %% [markdown]
# There are some useful inights that's are describing ...
# 1-Min age of employee is 18yrs,avg age 36yr,max age 60yr.
# 2-Min distance from home of employee is 1km,Avg 9km,max 29km.
# 3-Total no of employee in IBM company were 1470.
# 4-Min monthly Income of employee is 1000USD,Avg 6502USD,Max 20000USD

# %% [markdown]
# # Using HeatMap method for finding Corelation for O/P variable with other i/p variables

# %%
plt.figure(figsize=(40,40))
sns.heatmap(df.corr(),annot=True,linewidths=.5,linecolor="Black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking Outliers in given Dataset

# %%
df.plot(kind='box',subplots=True,layout=(9,6),figsize=(40,20))
# Out:
# Age                            AxesSubplot(0.125,0.808774;0.110714x0.0712264)
# Attrition                   AxesSubplot(0.257857,0.808774;0.110714x0.0712264)
# BusinessTravel              AxesSubplot(0.390714,0.808774;0.110714x0.0712264)
# DailyRate                   AxesSubplot(0.523571,0.808774;0.110714x0.0712264)
# Department                  AxesSubplot(0.656429,0.808774;0.110714x0.0712264)
# DistanceFromHome            AxesSubplot(0.789286,0.808774;0.110714x0.0712264)
# Education                      AxesSubplot(0.125,0.723302;0.110714x0.0712264)
# EducationField              AxesSubplot(0.257857,0.723302;0.110714x0.0712264)
# EmployeeNumber              AxesSubplot(0.390714,0.723302;0.110714x0.0712264)
# EnvironmentSatisfaction     AxesSubplot(0.523571,0.723302;0.110714x0.0712264)
# Gender                      AxesSubplot(0.656429,0.723302;0.110714x0.0712264)
# HourlyRate                  AxesSubplot(0.789286,0.723302;0.110714x0.0712264)
# ...

# %% [markdown]
# outliers are present in given dataset

# %% [markdown]
# # Use zscore method for removing outliers from given dataset

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
z
# Out:
#            Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     0.446350   2.280906        0.590048   0.742527    1.401512
# 1     1.322365   0.438422        0.913194   1.297775    0.493817
# 2     0.008343   2.280906        0.590048   1.414363    0.493817
# 3     0.429664   0.438422        0.913194   1.461466    0.493817
# 4     1.086676   0.438422        0.590048   0.524295    0.493817
# ...        ...        ...             ...        ...         ...
# 1465  0.101159   0.438422        0.913194   0.202082    0.493817
# 1466  0.227347   0.438422        0.590048   0.469754    0.493817
# 1467  1.086676   0.438422        0.590048   1.605183    0.493817
# 1468  1.322365   0.438422        0.913194   0.546677    1.401512
# 1469  0.320163   0.438422        0.590048   0.432568    0.493817
#
#       DistanceFromHome  Education  EducationField  EmployeeNumber  \
# 0             1.010909   0.891688        0.937414        1.701283
# ...

# %%
thresold=3
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([31, 30, 28, 30, 29, 30, 25, 25, 28, 30, 29, 30, 31, 25, 28, 30, 31,
#        30, 25, 31, 28, 29, 30, 29, 31, 28, 30, 25, 28, 29, 30, 30, 31, 25,
# ...

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print('Old_dataframe',df.shape)
print('new_dataframe',df_new.shape)
print("reduction in rows",df.shape[0]-df_new.shape[0])
# Out:
# Old_dataframe (1470, 32)
# new_dataframe (1387, 32)
# reduction in rows 83

# %%
Percentage_dataloss=(1470-1387)/1470*100

# %%
Percentage_dataloss
# Out:
# 5.646258503401361

# %% [markdown]
# # spliting the Data for Training & Testing phase

# %%
x=df_new.drop('Attrition',axis=1)

# %%
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41             2.0       1102         2.0                 1          2
# 1      49             1.0        279         1.0                 8          1
# 2      37             2.0       1373         1.0                 2          2
# 3      33             1.0       1392         1.0                 3          4
# 4      27             2.0        591         1.0                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36             1.0        884         1.0                23          2
# 1466   39             2.0        613         1.0                 6          1
# 1467   27             2.0        155         1.0                 4          3
# 1468   49             1.0       1023         2.0                 2          3
# 1469   34             2.0        628         1.0                 8          3
#
# ...

# %%
y=df_new['Attrition']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1387, dtype: int64

# %% [markdown]
# # check skewness present in Datset

# %%
x.skew()
# Out:
# Age                         0.472280
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EmployeeNumber              0.018931
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# ...

# %%
df.plot(kind='density',subplots=True,layout=(8,6),figsize=(40,32))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %% [markdown]
# there are skewness present in giveb Dataset

# %% [markdown]
# # Transformimg Data to remove skewness

# %% [markdown]
# Using the power transforming method to remove Skewness present in the given dataset

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 0.61013332,  0.63872976,  0.75061538, ...,  0.29052433,
#         -1.07353381,  0.58217664],
#        [ 1.37182974, -1.38077628, -1.34337244, ...,  1.0065754 ,
#          0.19316755,  1.01807316],
#        [ 0.18248603,  0.63872976,  1.33708042, ..., -1.57181404,
#         -1.07353381, -1.52842596],
#        ...,
#        [-1.0804891 ,  0.63872976, -1.75453754, ..., -0.39076907,
#         -1.07353381,  0.01867962],
#        [ 1.37182974, -1.38077628,  0.57328582, ...,  0.79376377,
#         -1.07353381,  1.20578193],
#        [-0.16377603,  0.63872976, -0.37222758, ..., -0.01873824,
#          0.19316755, -0.3478709 ]])

# %% [markdown]
# # MIN values & MAX values difference is higher in Describe dataset so use the scaling method to scale the data

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.61013332,  0.63872976,  0.75061538, ...,  0.29052433,
#         -1.07353381,  0.58217664],
#        [ 1.37182974, -1.38077628, -1.34337244, ...,  1.0065754 ,
#          0.19316755,  1.01807316],
#        [ 0.18248603,  0.63872976,  1.33708042, ..., -1.57181404,
#         -1.07353381, -1.52842596],
#        ...,
#        [-1.0804891 ,  0.63872976, -1.75453754, ..., -0.39076907,
#         -1.07353381,  0.01867962],
#        [ 1.37182974, -1.38077628,  0.57328582, ...,  0.79376377,
#         -1.07353381,  1.20578193],
#        [-0.16377603,  0.63872976, -0.37222758, ..., -0.01873824,
#          0.19316755, -0.3478709 ]])

# %% [markdown]
# # Model Selection

# %% [markdown]
# # label or O/P is in Binary form so use Linear model & clasification Model

# %% [markdown]
# LogisticRegression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
lg=LogisticRegression()

# %%
for i in range(0,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=i)
        lg.fit(train_x,train_y)
        lgpred=lg.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,lgpred)}")
        print(f"at random_state{i},the training accuracy is: =   {lg.score(train_x,train_y)}")
# Out:
# at random_state0,the testing accuracy score is := 0.8812949640287769
# at random_state0,the training accuracy is: =   0.8782687105500451
# at random_state1,the testing accuracy score is := 0.8525179856115108
# at random_state1,the training accuracy is: =   0.8854824165915239
# at random_state2,the testing accuracy score is := 0.8705035971223022
# at random_state2,the training accuracy is: =   0.8827772768259693
# at random_state3,the testing accuracy score is := 0.8705035971223022
# at random_state3,the training accuracy is: =   0.8836789900811542
# at random_state4,the testing accuracy score is := 0.8453237410071942
# at random_state4,the training accuracy is: =   0.8944995491433724
# at random_state5,the testing accuracy score is := 0.8381294964028777
# at random_state5,the training accuracy is: =   0.8890892696122633
# at random_state6,the testing accuracy score is := 0.9136690647482014
# at random_state6,the training accuracy is: =   0.872858431018936
# ...

# %%
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=55)
        lg.fit(train_x,train_y)
        lgpred=lg.predict(test_x)
        print(f"at random_state{55},the testing accuracy score is := {accuracy_score(test_y,lgpred)}")
        print(f"at random_state{55},the training accuracy is: =   {lg.score(train_x,train_y)}")
# Out:
# at random_state55,the testing accuracy score is := 0.9064748201438849
# at random_state55,the training accuracy is: =   0.872858431018936

# %% [markdown]
# # AUC & ROC Curve

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=lg.predict_proba(test_x)[:,1]

# %%
y_pred_prob
# Out:
# array([3.63668793e-02, 4.54947413e-01, 8.88610558e-03, 4.27038596e-03,
#        7.27253733e-01, 3.49811652e-01, 2.76157534e-02, 2.97991736e-01,
#        2.05310583e-03, 7.14374204e-02, 2.54284187e-02, 5.88770381e-01,
#        5.10621122e-02, 4.98318979e-02, 3.97331930e-02, 3.76357258e-03,
#        3.32167522e-02, 1.94523298e-01, 1.99571668e-02, 2.06936150e-03,
#        5.38540426e-02, 1.81814759e-02, 1.03495347e-02, 1.48531478e-02,
#        4.79992013e-01, 1.33000106e-02, 8.25275752e-01, 2.22517156e-01,
#        3.10206038e-02, 8.92701044e-02, 1.56818082e-02, 3.63848944e-03,
#        4.00531594e-03, 4.77285535e-02, 2.14659157e-02, 6.33489397e-02,
#        1.31018594e-02, 1.83836646e-02, 1.70530957e-01, 2.66786064e-01,
#        7.52608353e-02, 7.68270404e-02, 6.25857732e-01, 1.76383409e-01,
#        2.04847796e-02, 3.29967407e-02, 1.84074125e-01, 2.71675909e-01,
#        2.97995982e-01, 3.14457275e-02, 2.84772468e-02, 5.98739001e-03,
# ...

# %%
fpr,tpr,thresold=roc_curve(test_y,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.00414938, 0.00414938,
#        0.01659751, 0.01659751, 0.02489627, 0.02489627, 0.02904564,
#        0.02904564, 0.05394191, 0.05394191, 0.07053942, 0.07053942,
#        0.07883817, 0.07883817, 0.09543568, 0.09543568, 0.1120332 ,
#        0.1120332 , 0.15352697, 0.15352697, 0.17012448, 0.17012448,
#        0.17842324, 0.17842324, 0.18672199, 0.18672199, 0.34854772,
#        0.34854772, 0.38589212, 0.38589212, 0.39004149, 0.39004149,
#        0.43983402, 0.43983402, 0.56431535, 0.56431535, 0.57676349,
#        0.57676349, 0.593361  , 0.593361  , 0.70954357, 0.70954357,
#        0.83817427, 0.83817427, 0.94190871, 0.94190871, 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.02702703, 0.05405405, 0.05405405, 0.27027027,
#        0.27027027, 0.32432432, 0.32432432, 0.35135135, 0.35135135,
#        0.37837838, 0.37837838, 0.40540541, 0.40540541, 0.43243243,
#        0.43243243, 0.51351351, 0.51351351, 0.59459459, 0.59459459,
#        0.62162162, 0.62162162, 0.64864865, 0.64864865, 0.67567568,
#        0.67567568, 0.7027027 , 0.7027027 , 0.72972973, 0.72972973,
#        0.75675676, 0.75675676, 0.78378378, 0.78378378, 0.81081081,
#        0.81081081, 0.83783784, 0.83783784, 0.86486486, 0.86486486,
#        0.89189189, 0.89189189, 0.91891892, 0.91891892, 0.94594595,
#        0.94594595, 0.97297297, 0.97297297, 1.        , 1.        ])

# %%
thresold
# Out:
# array([           inf, 9.36858082e-01, 9.23510132e-01, 9.10354318e-01,
#        6.54955280e-01, 6.25857732e-01, 6.08346155e-01, 5.96989199e-01,
#        5.95116235e-01, 5.88770381e-01, 5.83116047e-01, 5.23038942e-01,
#        5.09186756e-01, 4.74506573e-01, 4.54947413e-01, 4.31943336e-01,
#        4.07185350e-01, 3.71552794e-01, 3.61320434e-01, 3.26302095e-01,
#        3.15504760e-01, 2.74419742e-01, 2.71675909e-01, 2.39587924e-01,
#        2.37745023e-01, 2.24923064e-01, 2.22517156e-01, 2.19701038e-01,
#        2.19096131e-01, 1.16585001e-01, 1.15816050e-01, 9.78631557e-02,
#        9.70921391e-02, 9.26214836e-02, 9.17385370e-02, 7.68270404e-02,
#        7.67148724e-02, 4.59617011e-02, 4.46284124e-02, 4.14152452e-02,
#        4.14093713e-02, 3.97375492e-02, 3.97331930e-02, 2.11640458e-02,
#        2.08724044e-02, 1.25202196e-02, 1.20360226e-02, 3.90231701e-03,
#        3.83161429e-03, 2.33186466e-04])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label="Logistic Regression")
plt.xlabel("False Postive Rate")
plt.ylabel("True Postive Rate")
plt.title("Logistic Regression")
plt.show()

# %%
roc_score=roc_auc_score(test_y,y_pred_prob)
roc_score
# Out:
# 0.8011663115397556

# %% [markdown]
# Hence the roc_auc score for Logistic Regression Model is 80.1%

# %% [markdown]
# # Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)
svc=SVC()
gnb= GaussianNB()
dtc=DecisionTreeClassifier()

# %% [markdown]
# # Use KNeighbors Model

# %%
for i in range(2,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.22,random_state=i)

        knn.fit(train_x,train_y)
        predknn=knn.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,predknn)}")
        print(f"at random_state{i},the training accuracy is: =      {knn.score(train_x,train_y)}")
        print(f"at random_state{i},the confusion_matrix is:=        {confusion_matrix(test_y,predknn)}")
        print(f"at random_state{i},the classification_report is:=   {classification_report(test_y,predknn)}")
        print("\n")
# Out:
# at random_state2,the testing accuracy score is := 0.8464052287581699
# at random_state2,the training accuracy is: =      0.8686401480111008
# at random_state2,the confusion_matrix is:=        [[255   1]
#  [ 46   4]]
# at random_state2,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.85      1.00      0.92       256
#          1.0       0.80      0.08      0.15        50
#
#     accuracy                           0.85       306
#    macro avg       0.82      0.54      0.53       306
# weighted avg       0.84      0.85      0.79       306
#
#
#
# at random_state3,the testing accuracy score is := 0.869281045751634
# at random_state3,the training accuracy is: =      0.8658649398704903
# at random_state3,the confusion_matrix is:=        [[259   5]
#  [ 35   7]]
# at random_state3,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93       264
# ...

# %% [markdown]
# accuracy for KNN model is less than  LogisticRegression so this model is not best fit for production purpose

# %% [markdown]
# # Use Gaussian Model

# %%
for i in range(2,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.22,random_state=i)

        gnb.fit(train_x,train_y)
        predgnb=gnb.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,predgnb)}")
        print(f"at random_state{i},the training accuracy is: =      {gnb.score(train_x,train_y)}")
        print(f"at random_state{i},the confusion_matrix is:=        {confusion_matrix(test_y,predgnb)}")
        print(f"at random_state{i},the classification_report is:=   {classification_report(test_y,predgnb)}")
        print("\n")
# Out:
# at random_state2,the testing accuracy score is := 0.8464052287581699
# at random_state2,the training accuracy is: =      0.8325624421831638
# at random_state2,the confusion_matrix is:=        [[232  24]
#  [ 23  27]]
# at random_state2,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.91      0.91      0.91       256
#          1.0       0.53      0.54      0.53        50
#
#     accuracy                           0.85       306
#    macro avg       0.72      0.72      0.72       306
# weighted avg       0.85      0.85      0.85       306
#
#
#
# at random_state3,the testing accuracy score is := 0.8235294117647058
# at random_state3,the training accuracy is: =      0.8140610545790934
# at random_state3,the confusion_matrix is:=        [[230  34]
#  [ 20  22]]
# at random_state3,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.87      0.89       264
# ...

# %% [markdown]
# accuracy for GAussian model  is less than than LogisticRegression so this model is not best fit for production purpose

# %% [markdown]
# # Use GRIDSEARCHCV

# %%
from sklearn.model_selection import GridSearchCV
dtc=DecisionTreeClassifier()

# %%
grid_param={'criterion':['ginni','entropy']}
grid=GridSearchCV(dtc,grid_param)
grid.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['ginni', 'entropy']})

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'entropy'}

# %% [markdown]
# # DTC Classifier

# %%
dtc=DecisionTreeClassifier(criterion='entropy')
dtc.fit(train_x,train_y)
dtcpred=dtc.predict(test_x)
print(f"dtc training score is:= {dtc.score(train_x,train_y)}")
print(f"dtc testing score is:= {accuracy_score(test_y,dtcpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,dtcpred)}")
print(f"classification report is:={classification_report(test_y,dtcpred)}")
# Out:
# dtc training score is:= 1.0
# dtc testing score is:= 0.7941176470588235
# confusion matrix is:=[[230  36]
#  [ 27  13]]
# classification report is:=              precision    recall  f1-score   support
#
#          0.0       0.89      0.86      0.88       266
#          1.0       0.27      0.33      0.29        40
#
#     accuracy                           0.79       306
#    macro avg       0.58      0.59      0.59       306
# weighted avg       0.81      0.79      0.80       306

# %% [markdown]
# accuracy for dtc model is less than the LogisticRegression model

# %% [markdown]
# # SVC classifier

# %%
grid_param={'kernel':['rbf','poly','linear']}
grid=GridSearchCV(svc,grid_param)
grid.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=SVC(), param_grid={'kernel': ['rbf', 'poly', 'linear']})

# %%
print(grid.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
svc=SVC()
svc.fit(train_x,train_y)
svcpred=svc.predict(test_x)
print(f"svc training score is:= {svc.score(train_x,train_y)}")
print(f"svc testing score is:= {accuracy_score(test_y,svcpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,svcpred)}")
print(f"classification report is:={classification_report(test_y,svcpred)}")
# Out:
# svc training score is:= 0.9213691026827012
# svc testing score is:= 0.8856209150326797
# confusion matrix is:=[[259   7]
#  [ 28  12]]
# classification report is:=              precision    recall  f1-score   support
#
#          0.0       0.90      0.97      0.94       266
#          1.0       0.63      0.30      0.41        40
#
#     accuracy                           0.89       306
#    macro avg       0.77      0.64      0.67       306
# weighted avg       0.87      0.89      0.87       306

# %% [markdown]
# accuracy for svc model is less than the LogisticRegression model

# %% [markdown]
# # Ensemble Technique

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=550,random_state=42)
rf.fit(train_x,train_y)
rfpred=rf.predict(test_x)
print(f"rf training score is:= {rf.score(train_x,train_y)}")
print(f"rf testing score is:= {accuracy_score(test_y,rfpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,rfpred)}")
print(f"classification report is:={classification_report(test_y,rfpred)}")
# Out:
# rf training score is:= 1.0
# rf testing score is:= 0.8741007194244604
# confusion matrix is:=[[239   2]
#  [ 33   4]]
# classification report is:=              precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       241
#            1       0.67      0.11      0.19        37
#
#     accuracy                           0.87       278
#    macro avg       0.77      0.55      0.56       278
# weighted avg       0.85      0.87      0.83       278

# %% [markdown]
# accuracy for this Randomforestclassifier are less than the LogisticRegression

# %% [markdown]
# # Use Crossvaltidation Technique

# %% [markdown]
# check CV score for lg model

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score=cross_val_score(lg,x,y,cv=5)
mean_accuracy=cv_score.mean()

# %%
mean_accuracy
# Out:
# 0.8702205022985222

# %% [markdown]
# # check CV score for Random Forest Classifier model

# %%
cv_score=cross_val_score(rf,x,y,cv=5)
mean_accuracy=cv_score.mean()

# %%
mean_accuracy
# Out:
# 0.8543542061657533

# %% [markdown]
# mean accuracy for lg model is less than the rf model.

# %% [markdown]
# # Predicting the best performance for the given model

# %% [markdown]
# hence among all the model it is showing that RandomForestClassifier is the best performing model with testing accuracy score=87.4%.

# %% [markdown]
# # Save the model for Production purpose

# %%
import joblib
HR_employee_file=joblib.dump(rf,"HR_employee.obj")
HR_employee_file
# Out:
# ['HR_employee.obj']
